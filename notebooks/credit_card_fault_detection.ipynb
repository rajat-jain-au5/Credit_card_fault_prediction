# %%
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/credit_card_pw_hindi/main/creditCardFraud_28011964_120214.csv")

# %%
data.head(15)
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0       50000    1          2         1   57     -1      0     -1      0
# 1       50000    1          1         2   37      0      0      0      0
# 2      500000    1          1         2   29      0      0      0      0
# 3      100000    2          2         2   23      0     -1     -1      0
# 4      140000    2          3         1   28      0      0      2      0
# 5       20000    1          3         2   35     -2     -2     -2     -2
# 6      200000    2          3         2   34      0      0      2      0
# 7      260000    2          1         2   51     -1     -1     -1     -1
# 8      630000    2          2         2   41     -1      0     -1     -1
# 9       70000    1          2         2   30      1      2      2      0
# 10     250000    1          1         2   29      0      0      0      0
# 11      50000    2          3         3   23      1      2      0      0
# 12      20000    1          1         2   24      0      0      2      2
# 13     320000    1          1         1   49      0      0      0     -1
# 14     360000    2          1         1   49      1     -2     -2     -2
#
#     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0       0  ...      20940      19146      19131      2000     36681     10000
# 1       0  ...      19394      19619      20024      2500      1815       657
# 2       0  ...     542653     483003     473944     55000     40000     38000
# 3       0  ...        221       -159        567       380       601         0
# 4       0  ...      12211      11793       3719      3329         0       432
# 5      -1  ...          0      13007      13912         0         0         0
# 6       0  ...       2513       1828       3731      2306        12        50
# 7      -1  ...       8517      22287      13668     21818      9966      8583
# 8      -1  ...       6500       6500       2870      1000      6500      6500
# 9       0  ...      66782      36137      36894      3200         0      3000
# 10      0  ...      59696      56875      55512      3000      3000      3000
# 11      0  ...      28771      29531      30211         0      1500      1100
# 12      2  ...      18338      17905      19104      3200         0      1500
# 13     -1  ...      70074       5856     195599     10358     10000     75940
# 14     -2  ...          0          0          0         0         0         0
#
#     PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0       9000       689       679                           0
# 1       1000      1000       800                           0
# 2      20239     13750     13770                           0
# 3        581      1687      1542                           0
# 4       1000      1000      1000                           0
# 5      13007      1122         0                           0
# 6        300      3738        66                           0
# 7      22301         0      3640                           0
# 8       6500      2870         0                           0
# 9       3000      1500         0                           1
# 10      3000      3000      3000                           0
# 11      1200      1300      1100                           0
# 12         0      1650         0                           1
# 13     20000    195599     50000                           0
# 14         0         0         0                           0
#
# [15 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   1001 non-null   int64
#  1   SEX                         1001 non-null   int64
#  2   EDUCATION                   1001 non-null   int64
#  3   MARRIAGE                    1001 non-null   int64
#  4   AGE                         1001 non-null   int64
#  5   PAY_0                       1001 non-null   int64
#  6   PAY_2                       1001 non-null   int64
#  7   PAY_3                       1001 non-null   int64
#  8   PAY_4                       1001 non-null   int64
#  9   PAY_5                       1001 non-null   int64
#  10  PAY_6                       1001 non-null   int64
#  11  BILL_AMT1                   1001 non-null   int64
#  12  BILL_AMT2                   1001 non-null   int64
#  13  BILL_AMT3                   1001 non-null   int64
#  14  BILL_AMT4                   1001 non-null   int64
#  15  BILL_AMT5                   1001 non-null   int64
#  16  BILL_AMT6                   1001 non-null   int64
#  17  PAY_AMT1                    1001 non-null   int64
#  18  PAY_AMT2                    1001 non-null   int64
#  19  PAY_AMT3                    1001 non-null   int64
#  20  PAY_AMT4                    1001 non-null   int64
#  21  PAY_AMT5                    1001 non-null   int64
#  22  PAY_AMT6                    1001 non-null   int64
#  23  default payment next month  1001 non-null   int64
# dtypes: int64(24)
# memory usage: 187.8 KB

# %%
data.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# !pip install pandas-profiling

# restart the kernal
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting ydata-profiling (from pandas-profiling)
#   Downloading ydata_profiling-4.2.0-py2.py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.3/352.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy<1.11,>=1.4.1 in /home/admin1/.local/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (1.10.1)
# Collecting pandas!=1.4.0,<2,>1.1 (from ydata-profiling->pandas-profiling)
#   Downloading pandas-1.5.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 1.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib<4,>=3.2 in /home/admin1/.local/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (3.7.1)
# Collecting pydantic<2,>=1.8.1 (from ydata-profiling->pandas-profiling)
#   Downloading pydantic-1.10.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 1.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/admin1/Desktop/search/credi_card_fault_detection/venv/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (5.4.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/admin1/.local/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (3.1.2)
# Collecting visions[type_image_path]==0.7.5 (from ydata-profiling->pandas-profiling)
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 2.3 MB/s eta 0:00:0000:01
# Collecting numpy<1.24,>=1.16.0 (from ydata-profiling->pandas-profiling)
#   Downloading numpy-1.23.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 1.8 MB/s eta 0:00:0000:0100:01
# Collecting htmlmin==0.1.12 (from ydata-profiling->pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling->pandas-profiling)
#   Downloading phik-0.12.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests<3,>=2.24.0 in /home/admin1/Desktop/search/credi_card_fault_detection/venv/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (2.31.0)
# Collecting tqdm<5,>=4.48.2 (from ydata-profiling->pandas-profiling)
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /home/admin1/.local/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (0.12.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling->pandas-profiling)
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /home/admin1/Desktop/search/credi_card_fault_detection/venv/lib/python3.8/site-packages (from ydata-profiling->pandas-profiling) (0.14.0)
# Collecting typeguard<3,>=2.13.2 (from ydata-profiling->pandas-profiling)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling->pandas-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Collecting wordcloud>=1.9.1 (from ydata-profiling->pandas-profiling)
#   Downloading wordcloud-1.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (461 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.3/461.3 kB 2.0 MB/s eta 0:00:0000:0100:01
# Collecting dacite>=1.8 (from ydata-profiling->pandas-profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling->pandas-profiling)
#   Downloading PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 2.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow in /home/admin1/Desktop/search/credi_card_fault_detection/venv/lib/python3.8/site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (9.5.0)
# Requirement already satisfied: attrs>=19.3.0 in /home/admin1/.local/lib/python3.8/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (22.2.0)
# Collecting networkx>=2.4 (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.0 MB/s eta 0:00:0000:0100:01
# Collecting tangled-up-in-unicode>=0.0.4 (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 1.4 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: MarkupSafe>=2.0 in /home/admin1/.local/lib/python3.8/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/admin1/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/admin1/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/admin1/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/admin1/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/admin1/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/admin1/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/admin1/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/admin1/.local/lib/python3.8/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in /home/admin1/.local/lib/python3.8/site-packages (from pandas!=1.4.0,<2,>1.1->ydata-profiling->pandas-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /home/admin1/.local/lib/python3.8/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/admin1/Desktop/search/credi_card_fault_detection/venv/lib/python3.8/site-packages (from pydantic<2,>=1.8.1->ydata-profiling->pandas-profiling) (4.6.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/admin1/Desktop/search/credi_card_fault_detection/venv/lib/python3.8/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/admin1/Desktop/search/credi_card_fault_detection/venv/lib/python3.8/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/admin1/.local/lib/python3.8/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/admin1/.local/lib/python3.8/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2022.12.7)
# Requirement already satisfied: patsy>=0.5.2 in /home/admin1/Desktop/search/credi_card_fault_detection/venv/lib/python3.8/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.3)
# Requirement already satisfied: zipp>=3.1.0 in /home/admin1/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (3.15.0)
# Requirement already satisfied: six in /home/admin1/Desktop/search/credi_card_fault_detection/venv/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=3f747d17992b19b130d95cc99da82b82391aefecbd1cd0a08afe4ad4b1f9cb36
#   Stored in directory: /home/admin1/.cache/pip/wheels/23/14/6e/4be5bfeeb027f4939a01764b48edd5996acf574b0913fe5243
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tqdm, tangled-up-in-unicode, pydantic, numpy, networkx, multimethod, dacite, PyWavelets, pandas, visions, imagehash, wordcloud, phik, ydata-profiling, pandas-profiling
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.1
#     Uninstalling pandas-2.0.1:
#       Successfully uninstalled pandas-2.0.1
# Successfully installed PyWavelets-1.4.1 dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.9.1 networkx-3.1 numpy-1.23.5 pandas-1.5.3 pandas-profiling-3.6.6 phik-0.12.3 pydantic-1.10.9 tangled-up-in-unicode-0.2.0 tqdm-4.65.0 typeguard-2.13.3 visions-0.7.5 wordcloud-1.9.2 ydata-profiling-4.2.0

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(data, title="Pandas Profiling Report")

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/37 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
X=data.drop(labels=["default payment next month"],axis=1)

# %%
X
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
#       PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0         0  ...      35835      20940      19146      19131      2000
# 1         0  ...      57608      19394      19619      20024      2500
# 2         0  ...     445007     542653     483003     473944     55000
# 3         0  ...        601        221       -159        567       380
# 4         0  ...      12108      12211      11793       3719      3329
# ...     ...  ...        ...        ...        ...        ...       ...
# 996      -1  ...      67782      -2618      95748     101299      3320
# 997       0  ...       8441      97041     103541       3632      5000
# 998      -1  ...       1114        657       1332        780         0
# 999      -2  ...          0          0          0          0         0
# 1000     -2  ...       3420       2527          0          0      9664
#
#       PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0        36681     10000      9000       689       679
# 1         1815       657      1000      1000       800
# 2        40000     38000     20239     13750     13770
# 3          601         0       581      1687      1542
# 4            0       432      1000      1000      1000
# ...        ...       ...       ...       ...       ...
# 996       5000         0    100000      7186         0
# 997       2000     89000      6500        91      1504
# 998       2806      2256      2274       780         0
# 999          0         0         0         0         0
# 1000      3420      2612         0         0         0
#
# [1001 rows x 23 columns]

# %%
y=data["default payment next month"]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 996     0
# 997     0
# 998     0
# 999     1
# 1000    1
# Name: default payment next month, Length: 1001, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
#we did train and test split before only why because we dont want data leakage
x_train, x_test, y_train, y_test=train_test_split(X,y,test_size=0.25,random_state=50)

# %%
#preprocessing steps
from sklearn.preprocessing import StandardScaler
train_scaler=StandardScaler()
test_scaler=StandardScaler()

# %%
scaled_train_data=train_scaler.fit_transform(x_train)

# %%
scaled_test_data=train_scaler.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(scaled_train_data,y_train)
# Out:
# GaussianNB()

# %%
y_pred=clf.predict(scaled_test_data)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 69.7211155378486

# %%
param_grid = {"var_smoothing": [1e-9,0.1, 0.001, 0.5,0.05,0.01,1e-8,1e-7,1e-6,1e-10,1e-11]}

# %%
from sklearn.model_selection import GridSearchCV
gs=GridSearchCV(clf,param_grid=param_grid,cv=5,verbose=3)

# %%
gs.fit(scaled_train_data,y_train)
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [CV 1/5] END ...............var_smoothing=1e-09;, score=0.713 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-09;, score=0.707 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-09;, score=0.580 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-09;, score=0.780 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-09;, score=0.487 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.1;, score=0.693 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.1;, score=0.773 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.1;, score=0.700 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.1;, score=0.780 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.1;, score=0.633 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=0.001;, score=0.713 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=0.001;, score=0.707 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=0.001;, score=0.593 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=0.001;, score=0.780 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=0.001;, score=0.487 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.5;, score=0.740 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.5;, score=0.807 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.5;, score=0.767 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.5;, score=0.793 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.5;, score=0.773 total time=   0.0s
# [CV 1/5] END ................var_smoothing=0.05;, score=0.700 total time=   0.0s
# [CV 2/5] END ................var_smoothing=0.05;, score=0.747 total time=   0.0s
# [CV 3/5] END ................var_smoothing=0.05;, score=0.647 total time=   0.0s
# [CV 4/5] END ................var_smoothing=0.05;, score=0.787 total time=   0.0s
# [CV 5/5] END ................var_smoothing=0.05;, score=0.540 total time=   0.0s
# [CV 1/5] END ................var_smoothing=0.01;, score=0.720 total time=   0.0s
# [CV 2/5] END ................var_smoothing=0.01;, score=0.713 total time=   0.0s
# [CV 3/5] END ................var_smoothing=0.01;, score=0.607 total time=   0.0s
# [CV 4/5] END ................var_smoothing=0.01;, score=0.780 total time=   0.0s
# [CV 5/5] END ................var_smoothing=0.01;, score=0.500 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-08;, score=0.713 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-08;, score=0.707 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-08;, score=0.580 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-08;, score=0.780 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-08;, score=0.487 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-07;, score=0.713 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-07;, score=0.707 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-07;, score=0.580 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-07;, score=0.780 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-07;, score=0.487 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-06;, score=0.713 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-06;, score=0.707 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-06;, score=0.580 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-06;, score=0.780 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-06;, score=0.487 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-10;, score=0.713 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-10;, score=0.707 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-10;, score=0.580 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-10;, score=0.780 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-10;, score=0.487 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=1e-11;, score=0.713 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-11;, score=0.707 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-11;, score=0.580 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-11;, score=0.780 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-11;, score=0.487 total time=   0.0s
# GridSearchCV(cv=5, estimator=GaussianNB(),
#              param_grid={'var_smoothing': [1e-09, 0.1, 0.001, 0.5, 0.05, 0.01,
#                                            1e-08, 1e-07, 1e-06, 1e-10, 1e-11]},
#              verbose=3)

# %%
gs.cv_results_
# Out:
# {'mean_fit_time': array([0.0053267 , 0.00365567, 0.00440059, 0.00335422, 0.00337353,
#         0.00447345, 0.0035779 , 0.00469098, 0.01073689, 0.00618877,
#         0.00491567]),
#  'std_fit_time': array([0.00242906, 0.00083626, 0.00073514, 0.00080489, 0.00123098,
#         0.00195531, 0.00242803, 0.00290984, 0.00588444, 0.00368866,
#         0.00189747]),
#  'mean_score_time': array([0.00374823, 0.00252066, 0.00223846, 0.00271811, 0.00321512,
#         0.00376968, 0.00176086, 0.00317712, 0.00244021, 0.00381999,
#         0.00252304]),
#  'std_score_time': array([0.00218728, 0.00062285, 0.00045984, 0.00079706, 0.00078787,
#         0.00196251, 0.00017686, 0.0013592 , 0.00158683, 0.00126228,
#         0.00060993]),
#  'param_var_smoothing': masked_array(data=[1e-09, 0.1, 0.001, 0.5, 0.05, 0.01, 1e-08, 1e-07,
#                     1e-06, 1e-10, 1e-11],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'var_smoothing': 1e-09},
#   {'var_smoothing': 0.1},
#   {'var_smoothing': 0.001},
#   {'var_smoothing': 0.5},
#   {'var_smoothing': 0.05},
#   {'var_smoothing': 0.01},
#   {'var_smoothing': 1e-08},
#   {'var_smoothing': 1e-07},
#   {'var_smoothing': 1e-06},
#   {'var_smoothing': 1e-10},
#   {'var_smoothing': 1e-11}],
#  'split0_test_score': array([0.71333333, 0.69333333, 0.71333333, 0.74      , 0.7       ,
#         0.72      , 0.71333333, 0.71333333, 0.71333333, 0.71333333,
#         0.71333333]),
#  'split1_test_score': array([0.70666667, 0.77333333, 0.70666667, 0.80666667, 0.74666667,
#         0.71333333, 0.70666667, 0.70666667, 0.70666667, 0.70666667,
#         0.70666667]),
#  'split2_test_score': array([0.58      , 0.7       , 0.59333333, 0.76666667, 0.64666667,
#         0.60666667, 0.58      , 0.58      , 0.58      , 0.58      ,
#         0.58      ]),
#  'split3_test_score': array([0.78      , 0.78      , 0.78      , 0.79333333, 0.78666667,
#         0.78      , 0.78      , 0.78      , 0.78      , 0.78      ,
#         0.78      ]),
#  'split4_test_score': array([0.48666667, 0.63333333, 0.48666667, 0.77333333, 0.54      ,
#         0.5       , 0.48666667, 0.48666667, 0.48666667, 0.48666667,
#         0.48666667]),
#  'mean_test_score': array([0.65333333, 0.716     , 0.656     , 0.776     , 0.684     ,
#         0.664     , 0.65333333, 0.65333333, 0.65333333, 0.65333333,
#         0.65333333]),
#  'std_test_score': array([0.10549355, 0.05474791, 0.10376041, 0.02293953, 0.08585259,
#         0.09920573, 0.10549355, 0.10549355, 0.10549355, 0.10549355,
#         0.10549355]),
#  'rank_test_score': array([6, 2, 5, 1, 3, 4, 6, 6, 6, 6, 6], dtype=int32)}

# %%
gs.best_estimator_
# Out:
# GaussianNB(var_smoothing=0.5)

# %%
clf2 = GaussianNB(var_smoothing=0.5)
clf2.fit(scaled_train_data,y_train)
y_pred2=clf2.predict(scaled_test_data)
accuracy_score(y_test,y_pred2)*100
# Out:
# 80.0796812749004

# %%
xgboost?
random forst?

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier()

# %%
xgb.fit(scaled_train_data,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred3=xgb.predict(scaled_test_data)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.7689243027888446

# %%
param_grid_xgboost = { "n_estimators": [50,100, 130],
                        "max_depth": range(3,11,1),
                      "random_state":[0,50,100]
                     }

# Creating an object of the Grid Search class
grid= GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid_xgboost,verbose=3,cv=5,n_jobs=-1)

# %%
grid.fit(scaled_train_data,y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END max_depth=3, n_estimators=50, random_state=0;, score=0.740 total time=   0.4s
# [CV 2/5] END max_depth=3, n_estimators=50, random_state=0;, score=0.747 total time=   0.6s
# [CV 5/5] END max_depth=3, n_estimators=50, random_state=0;, score=0.787 total time=   0.6s
# [CV 1/5] END max_depth=3, n_estimators=50, random_state=50;, score=0.740 total time=   0.4s
# [CV 3/5] END max_depth=3, n_estimators=50, random_state=50;, score=0.800 total time=   0.4s
# [CV 3/5] END max_depth=3, n_estimators=50, random_state=0;, score=0.800 total time=   0.6s
# [CV 2/5] END max_depth=3, n_estimators=50, random_state=50;, score=0.747 total time=   0.8s
# [CV 4/5] END max_depth=3, n_estimators=50, random_state=0;, score=0.787 total time=   0.6s
# [CV 4/5] END max_depth=3, n_estimators=50, random_state=50;, score=0.787 total time=   0.5s
# [CV 2/5] END max_depth=3, n_estimators=50, random_state=100;, score=0.747 total time=   0.4s
# [CV 5/5] END max_depth=3, n_estimators=50, random_state=50;, score=0.787 total time=   0.6s
# [CV 1/5] END max_depth=3, n_estimators=50, random_state=100;, score=0.740 total time=   0.7s
# [CV 4/5] END max_depth=3, n_estimators=50, random_state=100;, score=0.787 total time=   0.4s
# [CV 5/5] END max_depth=3, n_estimators=50, random_state=100;, score=0.787 total time=   0.5s
# [CV 3/5] END max_depth=3, n_estimators=50, random_state=100;, score=0.800 total time=   0.9s
# [CV 3/5] END max_depth=3, n_estimators=100, random_state=0;, score=0.807 total time=   0.8s
# [CV 1/5] END max_depth=3, n_estimators=100, random_state=0;, score=0.707 total time=   1.7s
# [CV 5/5] END max_depth=3, n_estimators=100, random_state=0;, score=0.793 total time=   0.8s
# [CV 4/5] END max_depth=3, n_estimators=100, random_state=0;, score=0.787 total time=   1.5s
# [CV 2/5] END max_depth=3, n_estimators=100, random_state=0;, score=0.753 total time=   2.1s
# [CV 1/5] END max_depth=3, n_estimators=100, random_state=50;, score=0.707 total time=   1.1s
# [CV 3/5] END max_depth=3, n_estimators=100, random_state=50;, score=0.807 total time=   1.1s
# [CV 2/5] END max_depth=3, n_estimators=100, random_state=50;, score=0.753 total time=   1.2s
# [CV 4/5] END max_depth=3, n_estimators=100, random_state=50;, score=0.787 total time=   1.2s
# [CV 1/5] END max_depth=3, n_estimators=100, random_state=100;, score=0.707 total time=   0.7s
# [CV 5/5] END max_depth=3, n_estimators=100, random_state=50;, score=0.793 total time=   1.3s
# [CV 3/5] END max_depth=3, n_estimators=100, random_state=100;, score=0.807 total time=   1.0s
# [CV 4/5] END max_depth=3, n_estimators=100, random_state=100;, score=0.787 total time=   0.9s
# [CV 2/5] END max_depth=3, n_estimators=100, random_state=100;, score=0.753 total time=   1.6s
# [CV 5/5] END max_depth=3, n_estimators=100, random_state=100;, score=0.793 total time=   1.2s
# [CV 1/5] END max_depth=3, n_estimators=130, random_state=0;, score=0.720 total time=   1.2s
# [CV 2/5] END max_depth=3, n_estimators=130, random_state=0;, score=0.767 total time=   1.3s
# [CV 3/5] END max_depth=3, n_estimators=130, random_state=0;, score=0.793 total time=   1.3s
# [CV 5/5] END max_depth=3, n_estimators=130, random_state=0;, score=0.773 total time=   0.9s
# [CV 4/5] END max_depth=3, n_estimators=130, random_state=0;, score=0.780 total time=   1.6s
# [CV 3/5] END max_depth=3, n_estimators=130, random_state=50;, score=0.793 total time=   0.9s
# [CV 1/5] END max_depth=3, n_estimators=130, random_state=50;, score=0.720 total time=   1.6s
# [CV 2/5] END max_depth=3, n_estimators=130, random_state=50;, score=0.767 total time=   1.9s
# [CV 5/5] END max_depth=3, n_estimators=130, random_state=50;, score=0.773 total time=   0.9s
# [CV 4/5] END max_depth=3, n_estimators=130, random_state=50;, score=0.780 total time=   1.6s
# [CV 1/5] END max_depth=3, n_estimators=130, random_state=100;, score=0.720 total time=   1.3s
# [CV 2/5] END max_depth=3, n_estimators=130, random_state=100;, score=0.767 total time=   1.2s
# [CV 1/5] END max_depth=4, n_estimators=50, random_state=0;, score=0.740 total time=   0.4s
# [CV 4/5] END max_depth=3, n_estimators=130, random_state=100;, score=0.780 total time=   1.2s
# [CV 3/5] END max_depth=3, n_estimators=130, random_state=100;, score=0.793 total time=   1.4s
# [CV 5/5] END max_depth=3, n_estimators=130, random_state=100;, score=0.773 total time=   1.2s
# [CV 2/5] END max_depth=4, n_estimators=50, random_state=0;, score=0.780 total time=   0.7s
# [CV 4/5] END max_depth=4, n_estimators=50, random_state=0;, score=0.800 total time=   0.5s
# [CV 3/5] END max_depth=4, n_estimators=50, random_state=0;, score=0.807 total time=   0.6s
# [CV 3/5] END max_depth=4, n_estimators=50, random_state=50;, score=0.807 total time=   0.4s
# [CV 5/5] END max_depth=4, n_estimators=50, random_state=0;, score=0.793 total time=   0.7s
# [CV 1/5] END max_depth=4, n_estimators=50, random_state=50;, score=0.740 total time=   0.6s
# [CV 2/5] END max_depth=4, n_estimators=50, random_state=50;, score=0.780 total time=   0.6s
# [CV 4/5] END max_depth=4, n_estimators=50, random_state=50;, score=0.800 total time=   0.4s
# [CV 5/5] END max_depth=4, n_estimators=50, random_state=50;, score=0.793 total time=   0.6s
# [CV 2/5] END max_depth=4, n_estimators=50, random_state=100;, score=0.780 total time=   0.5s
# [CV 1/5] END max_depth=4, n_estimators=50, random_state=100;, score=0.740 total time=   0.6s
# [CV 3/5] END max_depth=4, n_estimators=50, random_state=100;, score=0.807 total time=   0.6s
# [CV 4/5] END max_depth=4, n_estimators=50, random_state=100;, score=0.800 total time=   0.5s
# [CV 5/5] END max_depth=4, n_estimators=50, random_state=100;, score=0.793 total time=   0.6s
# [CV 1/5] END max_depth=4, n_estimators=100, random_state=0;, score=0.740 total time=   1.1s
# [CV 3/5] END max_depth=4, n_estimators=100, random_state=0;, score=0.807 total time=   0.8s
# [CV 4/5] END max_depth=4, n_estimators=100, random_state=0;, score=0.807 total time=   0.8s
# [CV 2/5] END max_depth=4, n_estimators=100, random_state=0;, score=0.800 total time=   1.3s
# [CV 1/5] END max_depth=4, n_estimators=100, random_state=50;, score=0.740 total time=   0.8s
# [CV 3/5] END max_depth=4, n_estimators=100, random_state=50;, score=0.807 total time=   0.8s
# [CV 5/5] END max_depth=4, n_estimators=100, random_state=0;, score=0.800 total time=   1.5s
# [CV 2/5] END max_depth=4, n_estimators=100, random_state=50;, score=0.800 total time=   1.4s
# [CV 4/5] END max_depth=4, n_estimators=100, random_state=50;, score=0.807 total time=   1.0s
# [CV 5/5] END max_depth=4, n_estimators=100, random_state=50;, score=0.800 total time=   0.8s
# [CV 2/5] END max_depth=4, n_estimators=100, random_state=100;, score=0.800 total time=   1.0s
# [CV 1/5] END max_depth=4, n_estimators=100, random_state=100;, score=0.740 total time=   1.2s
# [CV 3/5] END max_depth=4, n_estimators=100, random_state=100;, score=0.807 total time=   1.5s
# [CV 4/5] END max_depth=4, n_estimators=100, random_state=100;, score=0.807 total time=   1.3s
# [CV 5/5] END max_depth=4, n_estimators=100, random_state=100;, score=0.800 total time=   1.1s
# [CV 1/5] END max_depth=4, n_estimators=130, random_state=0;, score=0.740 total time=   1.3s
# [CV 3/5] END max_depth=4, n_estimators=130, random_state=0;, score=0.813 total time=   1.5s
# [CV 4/5] END max_depth=4, n_estimators=130, random_state=0;, score=0.800 total time=   1.3s
# [CV 2/5] END max_depth=4, n_estimators=130, random_state=0;, score=0.780 total time=   2.0s
# [CV 5/5] END max_depth=4, n_estimators=130, random_state=0;, score=0.787 total time=   1.4s
# [CV 4/5] END max_depth=4, n_estimators=130, random_state=50;, score=0.800 total time=   1.1s
# [CV 1/5] END max_depth=4, n_estimators=130, random_state=50;, score=0.740 total time=   1.8s
# [CV 2/5] END max_depth=4, n_estimators=130, random_state=50;, score=0.780 total time=   1.7s
# [CV 3/5] END max_depth=4, n_estimators=130, random_state=50;, score=0.813 total time=   1.6s
# [CV 1/5] END max_depth=4, n_estimators=130, random_state=100;, score=0.740 total time=   1.2s
# [CV 5/5] END max_depth=4, n_estimators=130, random_state=50;, score=0.787 total time=   1.4s
# [CV 2/5] END max_depth=4, n_estimators=130, random_state=100;, score=0.780 total time=   1.2s
# [CV 1/5] END max_depth=5, n_estimators=50, random_state=0;, score=0.753 total time=   0.4s
# [CV 3/5] END max_depth=4, n_estimators=130, random_state=100;, score=0.813 total time=   1.6s
# [CV 3/5] END max_depth=5, n_estimators=50, random_state=0;, score=0.807 total time=   0.4s
# [CV 2/5] END max_depth=5, n_estimators=50, random_state=0;, score=0.753 total time=   0.7s
# [CV 4/5] END max_depth=5, n_estimators=50, random_state=0;, score=0.807 total time=   0.4s
# [CV 5/5] END max_depth=4, n_estimators=130, random_state=100;, score=0.787 total time=   1.5s
# [CV 4/5] END max_depth=4, n_estimators=130, random_state=100;, score=0.800 total time=   1.6s
# [CV 1/5] END max_depth=5, n_estimators=50, random_state=50;, score=0.753 total time=   0.4s
# [CV 5/5] END max_depth=5, n_estimators=50, random_state=0;, score=0.813 total time=   0.8s
# [CV 4/5] END max_depth=5, n_estimators=50, random_state=50;, score=0.807 total time=   0.4s
# [CV 3/5] END max_depth=5, n_estimators=50, random_state=50;, score=0.807 total time=   0.6s
# [CV 2/5] END max_depth=5, n_estimators=50, random_state=50;, score=0.753 total time=   0.9s
# [CV 2/5] END max_depth=5, n_estimators=50, random_state=100;, score=0.753 total time=   0.4s
# [CV 5/5] END max_depth=5, n_estimators=50, random_state=50;, score=0.813 total time=   0.7s
# [CV 1/5] END max_depth=5, n_estimators=50, random_state=100;, score=0.753 total time=   0.8s
# [CV 4/5] END max_depth=5, n_estimators=50, random_state=100;, score=0.807 total time=   0.4s
# [CV 5/5] END max_depth=5, n_estimators=50, random_state=100;, score=0.813 total time=   0.6s
# [CV 3/5] END max_depth=5, n_estimators=50, random_state=100;, score=0.807 total time=   0.8s
# [CV 2/5] END max_depth=5, n_estimators=100, random_state=0;, score=0.767 total time=   0.8s
# [CV 1/5] END max_depth=5, n_estimators=100, random_state=0;, score=0.747 total time=   1.4s
# [CV 5/5] END max_depth=5, n_estimators=100, random_state=0;, score=0.807 total time=   0.7s
# [CV 4/5] END max_depth=5, n_estimators=100, random_state=0;, score=0.807 total time=   1.2s
# [CV 3/5] END max_depth=5, n_estimators=100, random_state=0;, score=0.820 total time=   1.5s
# [CV 2/5] END max_depth=5, n_estimators=100, random_state=50;, score=0.767 total time=   0.8s
# [CV 1/5] END max_depth=5, n_estimators=100, random_state=50;, score=0.747 total time=   1.3s
# [CV 3/5] END max_depth=5, n_estimators=100, random_state=50;, score=0.820 total time=   1.1s
# [CV 4/5] END max_depth=5, n_estimators=100, random_state=50;, score=0.807 total time=   1.2s
# [CV 2/5] END max_depth=5, n_estimators=100, random_state=100;, score=0.767 total time=   0.7s
# [CV 5/5] END max_depth=5, n_estimators=100, random_state=50;, score=0.807 total time=   1.3s
# [CV 1/5] END max_depth=5, n_estimators=100, random_state=100;, score=0.747 total time=   1.4s
# [CV 4/5] END max_depth=5, n_estimators=100, random_state=100;, score=0.807 total time=   0.7s
# [CV 3/5] END max_depth=5, n_estimators=100, random_state=100;, score=0.820 total time=   1.4s
# [CV 2/5] END max_depth=5, n_estimators=130, random_state=0;, score=0.760 total time=   0.9s
# [CV 5/5] END max_depth=5, n_estimators=100, random_state=100;, score=0.807 total time=   1.5s
# [CV 1/5] END max_depth=5, n_estimators=130, random_state=0;, score=0.733 total time=   1.5s
# [CV 3/5] END max_depth=5, n_estimators=130, random_state=0;, score=0.807 total time=   1.8s
# [CV 1/5] END max_depth=5, n_estimators=130, random_state=50;, score=0.733 total time=   0.9s
# [CV 5/5] END max_depth=5, n_estimators=130, random_state=0;, score=0.800 total time=   1.6s
# [CV 4/5] END max_depth=5, n_estimators=130, random_state=0;, score=0.800 total time=   1.8s
# [CV 2/5] END max_depth=5, n_estimators=130, random_state=50;, score=0.760 total time=   1.7s
# [CV 5/5] END max_depth=5, n_estimators=130, random_state=50;, score=0.800 total time=   1.0s
# [CV 3/5] END max_depth=5, n_estimators=130, random_state=50;, score=0.807 total time=   1.7s
# [CV 4/5] END max_depth=5, n_estimators=130, random_state=50;, score=0.800 total time=   1.6s
# [CV 4/5] END max_depth=5, n_estimators=130, random_state=100;, score=0.800 total time=   0.9s
# [CV 1/5] END max_depth=5, n_estimators=130, random_state=100;, score=0.733 total time=   2.0s
# [CV 2/5] END max_depth=5, n_estimators=130, random_state=100;, score=0.760 total time=   2.1s
# [CV 5/5] END max_depth=5, n_estimators=130, random_state=100;, score=0.800 total time=   0.9s
# [CV 3/5] END max_depth=5, n_estimators=130, random_state=100;, score=0.807 total time=   2.0s
# [CV 1/5] END max_depth=6, n_estimators=50, random_state=0;, score=0.780 total time=   0.7s
# [CV 3/5] END max_depth=6, n_estimators=50, random_state=0;, score=0.827 total time=   0.4s
# [CV 2/5] END max_depth=6, n_estimators=50, random_state=0;, score=0.753 total time=   0.6s
# [CV 4/5] END max_depth=6, n_estimators=50, random_state=0;, score=0.780 total time=   0.6s
# [CV 1/5] END max_depth=6, n_estimators=50, random_state=50;, score=0.780 total time=   0.5s
# [CV 5/5] END max_depth=6, n_estimators=50, random_state=0;, score=0.773 total time=   0.7s
# [CV 3/5] END max_depth=6, n_estimators=50, random_state=50;, score=0.827 total time=   0.6s
# [CV 2/5] END max_depth=6, n_estimators=50, random_state=50;, score=0.753 total time=   0.8s
# [CV 4/5] END max_depth=6, n_estimators=50, random_state=50;, score=0.780 total time=   0.5s
# [CV 2/5] END max_depth=6, n_estimators=50, random_state=100;, score=0.753 total time=   0.4s
# [CV 5/5] END max_depth=6, n_estimators=50, random_state=50;, score=0.773 total time=   0.6s
# [CV 1/5] END max_depth=6, n_estimators=50, random_state=100;, score=0.780 total time=   0.6s
# [CV 3/5] END max_depth=6, n_estimators=50, random_state=100;, score=0.827 total time=   0.6s
# [CV 4/5] END max_depth=6, n_estimators=50, random_state=100;, score=0.780 total time=   0.4s
# [CV 5/5] END max_depth=6, n_estimators=50, random_state=100;, score=0.773 total time=   0.8s
# [CV 2/5] END max_depth=6, n_estimators=100, random_state=0;, score=0.767 total time=   0.9s
# [CV 1/5] END max_depth=6, n_estimators=100, random_state=0;, score=0.767 total time=   1.4s
# [CV 3/5] END max_depth=6, n_estimators=100, random_state=0;, score=0.827 total time=   1.3s
# [CV 4/5] END max_depth=6, n_estimators=100, random_state=0;, score=0.780 total time=   1.2s
# [CV 5/5] END max_depth=6, n_estimators=100, random_state=0;, score=0.767 total time=   0.8s
# [CV 1/5] END max_depth=6, n_estimators=100, random_state=50;, score=0.767 total time=   1.4s
# [CV 3/5] END max_depth=6, n_estimators=100, random_state=50;, score=0.827 total time=   1.2s
# [CV 2/5] END max_depth=6, n_estimators=100, random_state=50;, score=0.767 total time=   1.8s
# [CV 5/5] END max_depth=6, n_estimators=100, random_state=50;, score=0.767 total time=   1.1s
# [CV 4/5] END max_depth=6, n_estimators=100, random_state=50;, score=0.780 total time=   2.0s
# [CV 1/5] END max_depth=6, n_estimators=100, random_state=100;, score=0.767 total time=   0.9s
# [CV 3/5] END max_depth=6, n_estimators=100, random_state=100;, score=0.827 total time=   0.8s
# [CV 2/5] END max_depth=6, n_estimators=100, random_state=100;, score=0.767 total time=   2.0s
# [CV 4/5] END max_depth=6, n_estimators=100, random_state=100;, score=0.780 total time=   1.6s
# [CV 1/5] END max_depth=6, n_estimators=130, random_state=0;, score=0.753 total time=   1.3s
# [CV 5/5] END max_depth=6, n_estimators=100, random_state=100;, score=0.767 total time=   2.1s
# [CV 4/5] END max_depth=6, n_estimators=130, random_state=0;, score=0.787 total time=   1.1s[CV 3/5] END max_depth=6, n_estimators=130, random_state=0;, score=0.833 total time=   1.6s
#
# [CV 2/5] END max_depth=6, n_estimators=130, random_state=0;, score=0.753 total time=   1.9s
# [CV 5/5] END max_depth=6, n_estimators=130, random_state=0;, score=0.760 total time=   1.4s
# [CV 1/5] END max_depth=6, n_estimators=130, random_state=50;, score=0.753 total time=   1.1s
# [CV 4/5] END max_depth=6, n_estimators=130, random_state=50;, score=0.787 total time=   1.0s
# [CV 2/5] END max_depth=6, n_estimators=130, random_state=50;, score=0.753 total time=   1.4s
# [CV 3/5] END max_depth=6, n_estimators=130, random_state=50;, score=0.833 total time=   1.8s
# [CV 5/5] END max_depth=6, n_estimators=130, random_state=50;, score=0.760 total time=   1.0s
# [CV 1/5] END max_depth=6, n_estimators=130, random_state=100;, score=0.753 total time=   1.2s
# [CV 2/5] END max_depth=6, n_estimators=130, random_state=100;, score=0.753 total time=   1.7s
# [CV 4/5] END max_depth=6, n_estimators=130, random_state=100;, score=0.787 total time=   1.2s
# [CV 5/5] END max_depth=6, n_estimators=130, random_state=100;, score=0.760 total time=   1.1s
# [CV 1/5] END max_depth=7, n_estimators=50, random_state=0;, score=0.733 total time=   0.7s
# [CV 3/5] END max_depth=6, n_estimators=130, random_state=100;, score=0.833 total time=   1.9s
# [CV 2/5] END max_depth=7, n_estimators=50, random_state=0;, score=0.787 total time=   0.5s
# [CV 3/5] END max_depth=7, n_estimators=50, random_state=0;, score=0.800 total time=   0.5s
# [CV 1/5] END max_depth=7, n_estimators=50, random_state=50;, score=0.733 total time=   0.6s
# [CV 5/5] END max_depth=7, n_estimators=50, random_state=0;, score=0.773 total time=   0.7s
# [CV 4/5] END max_depth=7, n_estimators=50, random_state=0;, score=0.773 total time=   0.8s
# [CV 2/5] END max_depth=7, n_estimators=50, random_state=50;, score=0.787 total time=   0.6s
# [CV 5/5] END max_depth=7, n_estimators=50, random_state=50;, score=0.773 total time=   0.6s
# [CV 3/5] END max_depth=7, n_estimators=50, random_state=50;, score=0.800 total time=   0.7s
# [CV 4/5] END max_depth=7, n_estimators=50, random_state=50;, score=0.773 total time=   0.8s
# [CV 1/5] END max_depth=7, n_estimators=50, random_state=100;, score=0.733 total time=   0.7s
# [CV 4/5] END max_depth=7, n_estimators=50, random_state=100;, score=0.773 total time=   0.5s
# [CV 3/5] END max_depth=7, n_estimators=50, random_state=100;, score=0.800 total time=   0.6s
# [CV 2/5] END max_depth=7, n_estimators=50, random_state=100;, score=0.787 total time=   0.7s
# [CV 5/5] END max_depth=7, n_estimators=50, random_state=100;, score=0.773 total time=   0.6s
# [CV 2/5] END max_depth=7, n_estimators=100, random_state=0;, score=0.767 total time=   0.9s
# [CV 1/5] END max_depth=7, n_estimators=100, random_state=0;, score=0.760 total time=   1.0s
# [CV 4/5] END max_depth=7, n_estimators=100, random_state=0;, score=0.773 total time=   1.2s
# [CV 3/5] END max_depth=7, n_estimators=100, random_state=0;, score=0.813 total time=   1.3s
# [CV 1/5] END max_depth=7, n_estimators=100, random_state=50;, score=0.760 total time=   0.8s
# [CV 5/5] END max_depth=7, n_estimators=100, random_state=0;, score=0.767 total time=   1.1s
# [CV 2/5] END max_depth=7, n_estimators=100, random_state=50;, score=0.767 total time=   1.2s
# [CV 5/5] END max_depth=7, n_estimators=100, random_state=50;, score=0.767 total time=   0.8s
# [CV 3/5] END max_depth=7, n_estimators=100, random_state=50;, score=0.813 total time=   1.4s
# [CV 4/5] END max_depth=7, n_estimators=100, random_state=50;, score=0.773 total time=   1.3s
# [CV 2/5] END max_depth=7, n_estimators=100, random_state=100;, score=0.767 total time=   0.7s
# [CV 3/5] END max_depth=7, n_estimators=100, random_state=100;, score=0.813 total time=   1.2s
# [CV 5/5] END max_depth=7, n_estimators=100, random_state=100;, score=0.767 total time=   0.7s
# [CV 1/5] END max_depth=7, n_estimators=100, random_state=100;, score=0.760 total time=   1.5s
# [CV 4/5] END max_depth=7, n_estimators=100, random_state=100;, score=0.773 total time=   1.2s
# [CV 2/5] END max_depth=7, n_estimators=130, random_state=0;, score=0.773 total time=   0.9s
# [CV 1/5] END max_depth=7, n_estimators=130, random_state=0;, score=0.767 total time=   1.3s
# [CV 3/5] END max_depth=7, n_estimators=130, random_state=0;, score=0.813 total time=   1.5s
# [CV 5/5] END max_depth=7, n_estimators=130, random_state=0;, score=0.767 total time=   0.9s
# [CV 4/5] END max_depth=7, n_estimators=130, random_state=0;, score=0.780 total time=   2.2s
# [CV 1/5] END max_depth=7, n_estimators=130, random_state=50;, score=0.767 total time=   1.8s
# [CV 3/5] END max_depth=7, n_estimators=130, random_state=50;, score=0.813 total time=   1.2s
# [CV 2/5] END max_depth=7, n_estimators=130, random_state=50;, score=0.773 total time=   2.4s
# [CV 1/5] END max_depth=7, n_estimators=130, random_state=100;, score=0.767 total time=   1.0s
# [CV 4/5] END max_depth=7, n_estimators=130, random_state=50;, score=0.780 total time=   2.0s
# [CV 3/5] END max_depth=7, n_estimators=130, random_state=100;, score=0.813 total time=   1.0s
# [CV 5/5] END max_depth=7, n_estimators=130, random_state=50;, score=0.767 total time=   2.1s
# [CV 2/5] END max_depth=7, n_estimators=130, random_state=100;, score=0.773 total time=   1.7s
# [CV 5/5] END max_depth=7, n_estimators=130, random_state=100;, score=0.767 total time=   1.2s
# [CV 1/5] END max_depth=8, n_estimators=50, random_state=0;, score=0.780 total time=   1.2s
# [CV 2/5] END max_depth=8, n_estimators=50, random_state=0;, score=0.767 total time=   0.9s
# [CV 4/5] END max_depth=7, n_estimators=130, random_state=100;, score=0.780 total time=   2.4s
# [CV 3/5] END max_depth=8, n_estimators=50, random_state=0;, score=0.820 total time=   0.5s
# [CV 2/5] END max_depth=8, n_estimators=50, random_state=50;, score=0.767 total time=   0.4s
# [CV 4/5] END max_depth=8, n_estimators=50, random_state=0;, score=0.780 total time=   1.0s
# [CV 5/5] END max_depth=8, n_estimators=50, random_state=0;, score=0.787 total time=   0.8s
# [CV 4/5] END max_depth=8, n_estimators=50, random_state=50;, score=0.780 total time=   0.5s
# [CV 1/5] END max_depth=8, n_estimators=50, random_state=50;, score=0.780 total time=   1.1s
# [CV 3/5] END max_depth=8, n_estimators=50, random_state=50;, score=0.820 total time=   0.8s
# [CV 1/5] END max_depth=8, n_estimators=50, random_state=100;, score=0.780 total time=   0.4s
# [CV 5/5] END max_depth=8, n_estimators=50, random_state=50;, score=0.787 total time=   0.8s
# [CV 2/5] END max_depth=8, n_estimators=50, random_state=100;, score=0.767 total time=   0.8s
# [CV 4/5] END max_depth=8, n_estimators=50, random_state=100;, score=0.780 total time=   0.6s
# [CV 3/5] END max_depth=8, n_estimators=50, random_state=100;, score=0.820 total time=   0.9s
# [CV 5/5] END max_depth=8, n_estimators=50, random_state=100;, score=0.787 total time=   0.8s
# [CV 2/5] END max_depth=8, n_estimators=100, random_state=0;, score=0.753 total time=   1.0s
# [CV 1/5] END max_depth=8, n_estimators=100, random_state=0;, score=0.773 total time=   1.5s
# [CV 3/5] END max_depth=8, n_estimators=100, random_state=0;, score=0.820 total time=   1.2s
# [CV 4/5] END max_depth=8, n_estimators=100, random_state=0;, score=0.773 total time=   1.5s
# [CV 2/5] END max_depth=8, n_estimators=100, random_state=50;, score=0.753 total time=   0.8s
# [CV 1/5] END max_depth=8, n_estimators=100, random_state=50;, score=0.773 total time=   1.3s
# [CV 5/5] END max_depth=8, n_estimators=100, random_state=0;, score=0.800 total time=   1.6s
# [CV 5/5] END max_depth=8, n_estimators=100, random_state=50;, score=0.800 total time=   0.8s
# [CV 3/5] END max_depth=8, n_estimators=100, random_state=50;, score=0.820 total time=   1.9s
# [CV 4/5] END max_depth=8, n_estimators=100, random_state=50;, score=0.773 total time=   1.7s
# [CV 2/5] END max_depth=8, n_estimators=100, random_state=100;, score=0.753 total time=   0.8s
# [CV 1/5] END max_depth=8, n_estimators=100, random_state=100;, score=0.773 total time=   1.9s
# [CV 5/5] END max_depth=8, n_estimators=100, random_state=100;, score=0.800 total time=   0.9s
# [CV 3/5] END max_depth=8, n_estimators=100, random_state=100;, score=0.820 total time=   2.0s
# [CV 4/5] END max_depth=8, n_estimators=100, random_state=100;, score=0.773 total time=   2.1s
# [CV 2/5] END max_depth=8, n_estimators=130, random_state=0;, score=0.753 total time=   1.1s
# [CV 1/5] END max_depth=8, n_estimators=130, random_state=0;, score=0.773 total time=   2.2s
# [CV 5/5] END max_depth=8, n_estimators=130, random_state=0;, score=0.793 total time=   1.0s
# [CV 3/5] END max_depth=8, n_estimators=130, random_state=0;, score=0.820 total time=   1.9s
# [CV 4/5] END max_depth=8, n_estimators=130, random_state=0;, score=0.773 total time=   1.8s
# [CV 2/5] END max_depth=8, n_estimators=130, random_state=50;, score=0.753 total time=   1.2s
# [CV 1/5] END max_depth=8, n_estimators=130, random_state=50;, score=0.773 total time=   2.0s
# [CV 4/5] END max_depth=8, n_estimators=130, random_state=50;, score=0.773 total time=   1.0s
# [CV 3/5] END max_depth=8, n_estimators=130, random_state=50;, score=0.820 total time=   1.7s
# [CV 5/5] END max_depth=8, n_estimators=130, random_state=50;, score=0.793 total time=   1.6s
# [CV 2/5] END max_depth=8, n_estimators=130, random_state=100;, score=0.753 total time=   1.1s
# [CV 1/5] END max_depth=8, n_estimators=130, random_state=100;, score=0.773 total time=   1.8s
# [CV 3/5] END max_depth=8, n_estimators=130, random_state=100;, score=0.820 total time=   1.9s
# [CV 4/5] END max_depth=8, n_estimators=130, random_state=100;, score=0.773 total time=   1.3s
# [CV 1/5] END max_depth=9, n_estimators=50, random_state=0;, score=0.773 total time=   0.7s
# [CV 5/5] END max_depth=8, n_estimators=130, random_state=100;, score=0.793 total time=   1.4s
# [CV 2/5] END max_depth=9, n_estimators=50, random_state=0;, score=0.727 total time=   0.5s
# [CV 1/5] END max_depth=9, n_estimators=50, random_state=50;, score=0.773 total time=   0.5s
# [CV 5/5] END max_depth=9, n_estimators=50, random_state=0;, score=0.793 total time=   0.9s
# [CV 4/5] END max_depth=9, n_estimators=50, random_state=0;, score=0.780 total time=   0.9s
# [CV 3/5] END max_depth=9, n_estimators=50, random_state=0;, score=0.833 total time=   1.1s
# [CV 3/5] END max_depth=9, n_estimators=50, random_state=50;, score=0.833 total time=   0.6s
# [CV 4/5] END max_depth=9, n_estimators=50, random_state=50;, score=0.780 total time=   0.6s
# [CV 5/5] END max_depth=9, n_estimators=50, random_state=50;, score=0.793 total time=   0.6s
# [CV 2/5] END max_depth=9, n_estimators=50, random_state=50;, score=0.727 total time=   0.9s
# [CV 1/5] END max_depth=9, n_estimators=50, random_state=100;, score=0.773 total time=   0.6s
# [CV 3/5] END max_depth=9, n_estimators=50, random_state=100;, score=0.833 total time=   0.6s
# [CV 2/5] END max_depth=9, n_estimators=50, random_state=100;, score=0.727 total time=   0.8s
# [CV 4/5] END max_depth=9, n_estimators=50, random_state=100;, score=0.780 total time=   0.7s
# [CV 5/5] END max_depth=9, n_estimators=50, random_state=100;, score=0.793 total time=   0.7s
# [CV 3/5] END max_depth=9, n_estimators=100, random_state=0;, score=0.833 total time=   1.0s
# [CV 2/5] END max_depth=9, n_estimators=100, random_state=0;, score=0.727 total time=   1.1s
# [CV 1/5] END max_depth=9, n_estimators=100, random_state=0;, score=0.773 total time=   1.3s
# [CV 4/5] END max_depth=9, n_estimators=100, random_state=0;, score=0.780 total time=   1.2s
# [CV 5/5] END max_depth=9, n_estimators=100, random_state=0;, score=0.787 total time=   1.0s
# [CV 1/5] END max_depth=9, n_estimators=100, random_state=50;, score=0.773 total time=   1.3s
# [CV 2/5] END max_depth=9, n_estimators=100, random_state=50;, score=0.727 total time=   1.6s
# [CV 3/5] END max_depth=9, n_estimators=100, random_state=50;, score=0.833 total time=   1.5s
# [CV 4/5] END max_depth=9, n_estimators=100, random_state=50;, score=0.780 total time=   1.2s
# [CV 5/5] END max_depth=9, n_estimators=100, random_state=50;, score=0.787 total time=   1.0s
# [CV 1/5] END max_depth=9, n_estimators=100, random_state=100;, score=0.773 total time=   1.3s
# [CV 2/5] END max_depth=9, n_estimators=100, random_state=100;, score=0.727 total time=   1.1s
# [CV 3/5] END max_depth=9, n_estimators=100, random_state=100;, score=0.833 total time=   1.2s
# [CV 4/5] END max_depth=9, n_estimators=100, random_state=100;, score=0.780 total time=   1.2s
# [CV 5/5] END max_depth=9, n_estimators=100, random_state=100;, score=0.787 total time=   1.2s
# [CV 1/5] END max_depth=9, n_estimators=130, random_state=0;, score=0.773 total time=   1.1s
# [CV 2/5] END max_depth=9, n_estimators=130, random_state=0;, score=0.747 total time=   1.7s
# [CV 3/5] END max_depth=9, n_estimators=130, random_state=0;, score=0.827 total time=   1.7s
# [CV 5/5] END max_depth=9, n_estimators=130, random_state=0;, score=0.780 total time=   1.2s
# [CV 4/5] END max_depth=9, n_estimators=130, random_state=0;, score=0.787 total time=   1.7s
# [CV 1/5] END max_depth=9, n_estimators=130, random_state=50;, score=0.773 total time=   1.6s
# [CV 2/5] END max_depth=9, n_estimators=130, random_state=50;, score=0.747 total time=   1.7s
# [CV 3/5] END max_depth=9, n_estimators=130, random_state=50;, score=0.827 total time=   1.5s
# [CV 1/5] END max_depth=9, n_estimators=130, random_state=100;, score=0.773 total time=   1.0s
# [CV 4/5] END max_depth=9, n_estimators=130, random_state=50;, score=0.787 total time=   2.1s
# [CV 2/5] END max_depth=9, n_estimators=130, random_state=100;, score=0.747 total time=   1.6s
# [CV 5/5] END max_depth=9, n_estimators=130, random_state=50;, score=0.780 total time=   2.2s
# [CV 3/5] END max_depth=9, n_estimators=130, random_state=100;, score=0.827 total time=   1.1s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=0;, score=0.787 total time=   0.5s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=0;, score=0.767 total time=   0.8s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=0;, score=0.813 total time=   0.5s
# [CV 4/5] END max_depth=9, n_estimators=130, random_state=100;, score=0.787 total time=   2.2s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=0;, score=0.767 total time=   0.8s
# [CV 5/5] END max_depth=9, n_estimators=130, random_state=100;, score=0.780 total time=   2.1s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=0;, score=0.753 total time=   0.9s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=50;, score=0.767 total time=   0.6s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=50;, score=0.787 total time=   0.8s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=50;, score=0.753 total time=   0.5s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=50;, score=0.767 total time=   0.8s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=50;, score=0.813 total time=   1.0s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=100;, score=0.787 total time=   0.5s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=100;, score=0.767 total time=   0.8s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=100;, score=0.753 total time=   0.5s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=100;, score=0.813 total time=   1.0s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=100;, score=0.767 total time=   0.9s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=0;, score=0.753 total time=   0.8s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=0;, score=0.767 total time=   1.6s
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=0;, score=0.753 total time=   0.8s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=0;, score=0.820 total time=   1.6s
# [CV 4/5] END max_depth=10, n_estimators=100, random_state=0;, score=0.767 total time=   1.9s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=50;, score=0.820 total time=   0.8s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=50;, score=0.767 total time=   2.0s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=50;, score=0.753 total time=   1.7s
# [CV 4/5] END max_depth=10, n_estimators=100, random_state=50;, score=0.767 total time=   1.3s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=100;, score=0.767 total time=   1.1s
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=50;, score=0.753 total time=   1.8s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=100;, score=0.753 total time=   1.7s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=100;, score=0.820 total time=   1.8s[CV 4/5] END max_depth=10, n_estimators=100, random_state=100;, score=0.767 total time=   0.9s
#
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=100;, score=0.753 total time=   1.0s
# [CV 2/5] END max_depth=10, n_estimators=130, random_state=0;, score=0.753 total time=   1.3s
# [CV 1/5] END max_depth=10, n_estimators=130, random_state=0;, score=0.773 total time=   1.8s
# [CV 4/5] END max_depth=10, n_estimators=130, random_state=0;, score=0.773 total time=   1.4s
# [CV 3/5] END max_depth=10, n_estimators=130, random_state=0;, score=0.813 total time=   3.2s
# [CV 1/5] END max_depth=10, n_estimators=130, random_state=50;, score=0.773 total time=   2.1s
# [CV 2/5] END max_depth=10, n_estimators=130, random_state=50;, score=0.753 total time=   2.1s
# [CV 5/5] END max_depth=10, n_estimators=130, random_state=0;, score=0.760 total time=   2.8s
# [CV 3/5] END max_depth=10, n_estimators=130, random_state=50;, score=0.813 total time=   2.0s
# [CV 1/5] END max_depth=10, n_estimators=130, random_state=100;, score=0.773 total time=   1.5s
# [CV 4/5] END max_depth=10, n_estimators=130, random_state=50;, score=0.773 total time=   2.4s
# [CV 5/5] END max_depth=10, n_estimators=130, random_state=50;, score=0.760 total time=   2.8s
# [CV 2/5] END max_depth=10, n_estimators=130, random_state=100;, score=0.753 total time=   1.3s
# [CV 3/5] END max_depth=10, n_estimators=130, random_state=100;, score=0.813 total time=   1.4s
# [CV 4/5] END max_depth=10, n_estimators=130, random_state=100;, score=0.773 total time=   1.6s
# [CV 5/5] END max_depth=10, n_estimators=130, random_state=100;, score=0.760 total time=   1.1s
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_ca...t=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, reg_alpha=None,
#                                      reg_lambda=None, ...),
#              n_jobs=-1,
#              param_grid={'max_depth': range(3, 11),
#                          'n_estimators': [50, 100, 130],
#                          'random_state': [0, 50, 100]},
#              verbose=3)

# %%
grid.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=4, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
grid.best_params_
# Out:
# {'max_depth': 4, 'n_estimators': 100, 'random_state': 0}

# %%
xgb_new=XGBClassifier(max_depth=4, n_estimators=90, random_state=0)

# %%
y_pred4=xgb_new.fit(scaled_train_data,y_train).predict(scaled_test_data)

# %%
accuracy_score(y_test,y_pred4)
# Out:
# 0.7848605577689243
